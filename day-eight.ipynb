# %%
x="aditya" ##DAY01-OF-OOPS-TRAINING-ATTEND-BY-ADITYA-SONI

# %%
x
# Out:
# 'aditya'

# %%
#OOPS

# %%
#VISITORFORM: Custom DS

# %%
class visitorform:
    name=None
    contact=None
    email=None
    purpose=None

# %%
aditya=visitorform()

# %%
o=[6,7,8,9]

# %%
type(o)
# Out:
# list

# %%
type(aditya)
# Out:
# __main__.visitorform

# %%
print( aditya.contact )
# Out:
# None

# %%
print( aditya.name )
# Out:
# None

# %%
aditya.contact=9190909

# %%
print( aditya.contact )
# Out:
# 9190909

# %%
id(aditya)
# Out:
# 1585435983360

# %%
aditya.contact
# Out:
# 9190909

# %%
soni=visitorform()

# %%
id(soni)
# Out:
# 1585399022288

# %%
soni.__dict__
# Out:
# {}

# %%
soni.name="soni i"

# %%
soni.contact="89972"

# %%
print( soni.contact )
# Out:
# 89972

# %%
soni.email="soni1896@gmail.com"

# %%
print( soni.email )
# Out:
# soni1896@gmail.com
