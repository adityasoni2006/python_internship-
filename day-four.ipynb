# %%
def print_name():
    print("aadi") ##day4-perform-by-aditya-soni

# %%
print_name()
# Out:
# aadi

# %%
def print_name(a):
    print("aadi")

# %%
print_name("aditya-soni")
# Out:
# aadi

# %%
def multi_arg(*arg):
    print(arg)

# %%
multi_arg(1,2,3)
# Out:
# (1, 2, 3)

# %%
def add(a,b,c):
    return a + b + c

# %%
add (1,3,1)
# Out:
# 5

# %%
def student(**info):
    for key , value in info.items():
        print(key, ":", value)

# %%
tom_details = student (name = "aditya soni", contacts = 9079)
# Out:
# name : aditya soni
# contacts : 9079

# %%
def myfunc(a,b):
    return a+b , a-b

# %%
myfunc(14,2)
# Out:
# (16, 12)

# %%
def double(x):
    return x * 2

print(double(12))
# Out:
# 24

# %%
# !pip install tools

# %%
import math

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import random as r

# %%
r.randint(1,20)
# Out:
# 1

# %%
import datetime as d

# %%
print(d.datetime.today())
# Out:
# 2025-11-25 18:44:05.664727

# %%
try:
    no = int(input("Enter a number"))
    print = (10/no)
except ZeroDivisionError:
    print("Don't enter 0")
except ValueError:
    print("Enter only integer")
# Out:
# Enter a number 7
