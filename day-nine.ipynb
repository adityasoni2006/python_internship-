# %%
import smtplib ##day09-perorm-by-aditya soni

# %%
import ssl

# %%
from email.message import EmailMessage

# %%
email="adityaverma1896@gmail.com"
app_password="irzr dncn rypb byvx"
receiver="bajajvinamra076@gmail.com"

# %%
msg=EmailMessage()

# %%
msg["From"]=email
msg["To"]=receiver
msg["Subject"]="code for Python ..."

# %%
msg.set_content("This email was shared by Python ")

# %%
context=ssl.create_default_context()

# %%
with smtplib.SMTP_SSL("smtp.gmail.com",400,context=context) as server:
    server.login(email,app_password)
    server.send_message(msg)
    print("Mail sent")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 with smtplib.SMTP_SSL("smtp.gmail.com",400,context=context) as server:
#       2     server.login(email,app_password)
#       3     server.send_message(msg)
#
# File ~\anaconda3\Lib\smtplib.py:1022, in SMTP_SSL.__init__(self, host, port, local_hostname, timeout, source_address, context)
#    1020     context = ssl._create_stdlib_context()
#    1021 self.context = context
# -> 1022 SMTP.__init__(self, host, port, local_hostname, timeout,
#    1023               source_address)
#
# File ~\anaconda3\Lib\smtplib.py:255, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
#     252 self._auth_challenge_count = 0
#     254 if host:
# --> 255     (code, msg) = self.connect(host, port)
#     256     if code != 220:
#     257         self.close()
#
# ...
