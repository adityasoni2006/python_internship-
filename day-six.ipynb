# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return """
   <!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1" />
  <title>Profile Dashboard</title>
  <style>
    :root{
      --bg:#eef2f7;
      --card:#ffffff;
      --accent:#2563eb;
      --muted:#6b7280;
    }
    body{margin:0;font-family:Arial, sans-serif;background:var(--bg);color:#0f172a}
    header{background:var(--accent);color:white;padding:18px;font-size:24px;font-weight:bold;text-align:center}
    .container{max-width:900px;margin:30px auto;padding:20px}
    .card{background:var(--card);padding:26px;border-radius:14px;box-shadow:0 6px 18px rgba(0,0,0,0.08);}
    .profile-header{display:flex;align-items:center;gap:20px}
    .avatar{width:110px;height:110px;border-radius:14px;background:linear-gradient(135deg,var(--accent),#06b6d4);display:flex;align-items:center;justify-content:center;color:white;font-weight:bold;font-size:32px}
    h2{margin:0;margin-bottom:6px}
    .info{margin-top:20px}
    .info p{margin:6px 0;font-size:16px}
  </style>
</head>
<body>

  <header>Profile Dashboard</header>

  <div style="display:flex;justify-content:center;gap:12px;margin-top:20px;">
    <button style="padding:10px 20px;border:none;border-radius:8px;background:#2563eb;color:white;font-weight:bold;cursor:pointer;">Profile</button>
    <button style="padding:10px 20px;border:none;border-radius:8px;background:#2563eb;color:white;font-weight:bold;cursor:pointer;">Projects</button>
    <button style="padding:10px 20px;border:none;border-radius:8px;background:#2563eb;color:white;font-weight:bold;cursor:pointer;">Skills</button>
  </div>

  <div class="container">
    <div class="card">

      <div class="profile-header">
        <div class="avatar">MS</div>
        <div>
          <h2>Mansimran Singh</h2>
          <p style="color:var(--muted);margin:0;">Developer • Python & Automation Enthusiast</p>
        </div>
      </div>

      <div class="info">
        <p><strong>Full Name:</strong> Mansimran Singh</p>
        <p><strong>Age:</strong> 19 Years </p>
        <p><strong>Country:</strong> India</p>
        <p><strong>Interests:</strong> Coding, Python, Automation, Trading</p>
        
        <p><strong>Languages:</strong> English, Hindi</p>
        <p><strong>Hobbies:</strong> Learning tech, building tools, exploring trading strategies</p>
      </div>

    </div>
  </div>

</body>
</html>
    """
@app.route("/projects")
def projects():
    return """
    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>My Projects</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background: #f4f4f4;
            margin: 0;
            padding: 20px;
        }

        .container {
            max-width: 800px;
            margin: auto;
            background: white;
            padding: 25px;
            border-radius: 10px;
            box-shadow: 0 0 12px rgba(0,0,0,0.1);
        }

        h1 {
            text-align: center;
            color: #333;
        }

        .project-card {
            background: #e8ecf7;
            padding: 15px;
            border-radius: 8px;
            margin-bottom: 15px;
        }

        .back-btn {
            display: inline-block;
            margin-bottom: 20px;
            padding: 10px 18px;
            background: #2563eb;
            color: white;
            text-decoration: none;
            border-radius: 8px;
            font-weight: bold;
        }

    </style>
</head>
<body>

    <div class="container">
        <a href="index.html" class="back-btn">⬅ Back to Dashboard</a>
        <h1>My Projects</h1>

        <div class="project-card">
            <h3>ATM Transaction Program (Python)</h3>
            <p>A simple ATM system coded in Python that handles PIN verification, balance display, and withdrawals.</p>
        </div>

        <div class="project-card">
            <h3>Automated Calculator (Python)</h3>
            <p>A Python calculator program using loop statements that performs addition, subtraction, and multiplication automatically.</p>
        </div>

        <div class="project-card">
            <h3>Jarvis Voice Assistant (Python)</h3>
            <p>A Python-based voice assistant that performs tasks using speech commands, allowing hands-free control and automation.</p>
        </div>

    </div>

</body>
</html>

    """
@app.route("/skills")
def skills():
    return """
    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>My Skills</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background: #f4f4f4;
            margin: 0;
            padding: 20px;
        }

        .container {
            max-width: 800px;
            margin: auto;
            background: white;
            padding: 25px;
            border-radius: 10px;
            box-shadow: 0 0 12px rgba(0,0,0,0.1);
        }

        h1 {
            text-align: center;
            color: #333;
        }

        .section {
            margin-bottom: 25px;
        }

        ul {
            margin-top: 10px;
        }

        .back-btn {
            display: inline-block;
            margin-bottom: 20px;
            padding: 10px 18px;
            background: #2563eb;
            color: white;
            text-decoration: none;
            border-radius: 8px;
            font-weight: bold;
        }
    </style>
</head>
<body>

    <div class="container">
        <a href="index.html" class="back-btn">⬅ Back to Dashboard</a>

        <h1>My Skills</h1>

        <div class="section">
            <h2>Python</h2>
            <p>
                Python is a powerful, high-level programming language known for its simplicity and readability.
                It is widely used for web development, automation, data analysis, artificial intelligence,
                machine learning, and scripting. Python's clean and beginner-friendly syntax makes it easy to learn,
                while its extensive library support allows developers to build advanced projects efficiently.
                It is one of the most versatile languages and is used by developers, data scientists, and
                automation engineers around the world.
            </p>
        </div>

        <div class="section">
            <h2>Projects I Have Built</h2>
            <ul>
                <li>ATM Transaction Program (Python)</li>
                <li>Automated Calculator (Python)</li>
                <li>Jarvis Voice Assistant (Python)</li>
            </ul>
        </div>

    </div>

</body>
</html>

    """

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Nov/2025 22:40:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2025 22:41:03] "GET /projects HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2025 22:41:17] "GET /skills HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2025 23:09:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2025 23:09:49] "GET /projects HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2025 23:10:01] "GET /skiils HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Nov/2025 23:10:29] "GET /skills HTTP/1.1" 200 -

# %% [markdown]
# Tic Tac Toe

# %%
pip install pygame
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.init()
# Out:
# (5, 0)

# %%
import pygame
pygame.init()
screen = pygame.display.set_mode((600,600))
pygame.display.set_caption("X / O Game")
WHITE = (255,255,255)
BLACK = (0,0,0)
size = 200
board = [["","",""],
        ["","",""],
        ["","",""]]
player = "X"
font = pygame.font.Font(None,100)
run = True

while run:
    screen.fill(WHITE)
    pygame.draw.line(screen,BLACK,(200,0),(200,600),5)
    pygame.draw.line(screen,BLACK,(400,0),(400,600),5)
    pygame.draw.line(screen,BLACK,(0,200),(600,200),5)
    pygame.draw.line(screen,BLACK,(0,400),(600,400),5)
    for row in range(3):
        for col in range(3):
            if board[row][col] != "":
                text = font.render(board[row][col],True,BLACK)
                screen.blit(text,(col * size + 70, row * size + 50))
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            run = False
        if event.type == pygame.MOUSEBUTTONDOWN:
            mouse_x, mouse_y = pygame.mouse.get_pos()
            row = mouse_y //200
            col = mouse_x //200
            if board[row][col]== "":
                board[row][col] = player
                if player == "X":
                    player ="O"
                else:
                    player = "X"
    pygame.display.update()
pygame.quit()
