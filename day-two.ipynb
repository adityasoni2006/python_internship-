# %%
print("hello linux-world ltd.") #day2-perform-by-aditya-soni
# Out:
# hello linux-world ltd.

# %%
fruits=("apple","strwaberry","pineapple")
print(fruits)
# Out:
# ('apple', 'strwaberry', 'pineapple')

# %%
print(fruit[:2])
# Out:
# ('apple', 'strwaberry')

# %%
tuple
# Out:
# tuple

# %%
colors=("blue","black","grey")

# %%
print(colors)
# Out:
# ('blue', 'black', 'grey')

# %%
student={"name":'Aditya Soni',"age":18}

# %%
type(student)
# Out:
# dict

# %%
student["performance"]="A"
student["attendance"]=80

# %%
print(student)
# Out:
# {'name': 'Aditya Soni', 'age': 18, 'performance': 'A', 'attendance': 80}

# %%
del student["age"]

# %%
print(student)
# Out:
# {'name': 'Aditya Soni', 'performance': 'A', 'attendance': 80}

# %%
age=int(input("Enter your age : "))
if (age>18):
    print("You can watch the movie")
else:
    print("You can't watch the movie")
# Out:
# Enter your age :  20
# You can watch the movie

# %%
age=int(input("Enter your age : "))
# ticket= True
if (age>18):
    print("You can watch the movie")
elif(age<15):
    print("You can watch the movie with the parents")
else:
    print("Not  allowed")
# Out:
# Enter your age :  20
# You can watch the movie

# %%
age=int(input("Enter your age : "))
ticket= input("Enter 0 for True or 1 for False")
flag=bool(ticket)
print(flag)
if (age>18):
    print("Check your ticket")
    if not flag :
        print("You can't watch the movie")
    else:
        print("You can watch the movie")
elif(age<15):
    print("You can watch the movie with the parents")
else:
    print("Not  allowed")
# Out:
# Enter your age :  20
# Enter 0 for True or 1 for False true
# True
# Check your ticket
# You can watch the movie

# %%
if age<10 or age>15:
    print("Anyone was true")
# Out:
# Anyone was true

# %%
for i in range(20,2,-2):
    print(i)
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4

# %%
for i in range(9,1,-1):
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
for i in range(6,0,-1):
    print("*"*i)
# Out:
# ******
# *****
# ****
# ***
# **
# *

# %%
##THIS NUMBER IS POSITIVE,NEGATIVE,ZERO
number=int(input("Enter the number"))
if number>0:
    print("Positive number")
elif number<0:
    print("Negative number")
elif number==0:
    print("The number is 0")
else:
    print("The entered number is wrong")
# Out:
# Enter the number 9
# Positive number

# %%
##WEATHER A YEAR IS A LEAP YEAR
year=int(input("Enter the year"))
if year%4==0:
    print("The year is leap year")
else:
    print("The year is a normal year")
# Out:
# Enter the year 2025
# The year is a normal year

# %%
##PALINDROME NUMBER
number=int(input("Enter the number"))
number2=number
final_number=0
while(number!=0):
    add_number=number%10
    number=number//10
    final_number=final_number*10+add_number
if (final_number==number2):
    print("The number is pallindrome")
else:
    print("No")
# Out:
# Enter the number 182
# No

# %%
"#CALCULATOR"
choice = "0"

while choice != "4":
    print("""
    1. Addition
    2. Subtraction
    3. Multiplication
    4. Exit
    """)

    choice = input("Enter your choice: ")

    if choice == "1":
        num1 = int(input("Enter number 1: "))
        num2 = int(input("Enter number 2: "))
        print("Addition is:", num1 + num2)

    elif choice == "2":
        num1 = int(input("Enter number 1: "))
        num2 = int(input("Enter number 2: "))
        print("Subtraction is:", num1 - num2)

    elif choice == "3":
        num1 = int(input("Enter number 1: "))
        num2 = int(input("Enter number 2: "))
        print("Multiplication is:", num1 * num2)

    elif choice == "4":
        print("Exiting program...")

    else:
        print("Invalid choice! Please try again.")
# Out:
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Exit
# Enter your choice:  2+2
# Invalid choice! Please try again.
#
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Exit
# Enter your choice:  3
# Enter number 1:  3
# Enter number 2:  4
# Multiplication is: 12
#
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Exit

# %%
for i in range(1,10):
    if i==5:
        break
    print(i)

# %%
try:
    a = 10 / 0
except:
    print("Error occurred!")

# %%
# Withdrawing Exercise (Corrected & Clean Code)

balance = 85000
pin = 1978
attempts = 0

while attempts < 3:
    user_pin = input("Enter your PIN: ")

    # Check PIN is numeric
    if not user_pin.isdigit():
        print("PIN must be a number!")
        attempts += 1
        print(f"Attempts left: {3 - attempts}\n")
        continue

    user_pin = int(user_pin)

    # Match PIN
    if user_pin == pin:
        print("\nPIN verified successfully!")
        print("Select Operation:")
        print("1. Amount Deposit")
        print("2. Amount Withdrawal")

        choice = input("Enter your operation (1 or 2): ")

        if choice not in ["1", "2"]:
            print("Invalid choice!")
            break

        try:
            amount = int(input("Enter amount: "))
        except ValueError:
            print("Invalid input! Please enter amount in numbers only.")
            break

        # Deposit
        if choice == "1":
            balance += amount
            print(f"Amount Deposited Successfully! New Balance: {balance}")

        # Withdrawal
        elif choice == "2":
            if amount > balance:
                print("Insufficient balance!")
            else:
                balance -= amount
                print(f"Amount Withdrawn Successfully! Remaining Balance: {balance}")

        break

    else:
        print("Incorrect PIN!")
        attempts += 1
        print(f"Attempts left: {3 - attempts}\n")

# If 3 wrong attempts
if attempts == 3:
    print("Your card has been blocked due to 3 incorrect attempts.")
# Out:
# Enter your PIN:  1978
# PIN verified successfully!
# Select Operation:
# 1. Amount Deposit
# 2. Amount Withdrawal
# Enter your operation (1 or 2):  2
# Enter amount:  10500
# Amount Withdrawn Successfully! Remaining Balance: 74500

# %%
balance=5000
count=0
while True:
    pin=4343
    
    user_pin=int(input("Enter your pin"))
    
    if  user_pin ==pin:
        print("Your balance is : ", balance)
        amount=int(input("Enter the amount to withdraw"))
        if balance >= amount:
            print("Amount is withdrawn : ", amount)
            balance-=amount
            print("Current balance : ", balance)
        else:
            print("Invalid input")
            break
    else:
        print("Wrong pin entered")
        if count==2:
            break
        count+=1
# Out:
# Enter your pin 4343
# Your balance is :  5000
# Enter the amount to withdraw 1000
# Amount is withdrawn :  1000
# Current balance :  4000
# Enter your pin 4392
# Wrong pin entered
